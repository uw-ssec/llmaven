# %% [markdown]
# # RAG evaluation using TruLens
# This notebook sets up a RAG pipeline using LangChain, LlamaCpp, Qdrant (vector database), and TruLens for evaluation. The goal is to retrieve astrophysics-related information from a database and use a LLM (OLMo-7B-Instruct) to generate answers while evaluating the quality of responses using TruLens.
#
# ## 1. Import required libraries and dependencies

# %%
# !pip install openai trulens
# !pip install --no-deps trulens-apps-langchain
# !pip install trulens-providers-openai>=1.0.0

# %%
import os
import numpy as np
import pandas as pd
from datetime import datetime

from pathlib import Path

from langchain_core.runnables import RunnablePassthrough
from langchain_core.prompts import PromptTemplate
from langchain_community.llms import LlamaCpp
from langchain_qdrant import Qdrant
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_qdrant import Qdrant
from qdrant_client import QdrantClient
from langchain_core.callbacks import StreamingStdOutCallbackHandler
from langchain_core.output_parsers import StrOutputParser

from trulens.apps.app import instrument
from trulens.apps.langchain import TruChain
from trulens.core import TruSession, Feedback
from trulens.providers.openai import OpenAI

import warnings
warnings.filterwarnings("ignore")

# %%
# # Set the OpenAI API key for authentication (Replace with your actual API key)
# os.environ["OPENAI_API_KEY"] = "<API key>"

# %%
# import the function download_olmo_model from the ssec_tutorials repository
from ssec_tutorials import download_olmo_model
help(download_olmo_model)
# Out:
# Help on function download_olmo_model in module ssec_tutorials.setup:
#
# download_olmo_model(model_file: 'str | None' = None, force=False) -> 'Path'
#     Download the OLMO model from the Hugging Face model hub.
#
#     Parameters
#     ----------
#     model_file : str | None, optional
#         The name of the model file to download, by default None
#     force : bool, optional
#         Whether to force the download even if the file already exists, by default False
#
#     Returns
#     -------
#     pathlib.Path
#         The path to the downloaded model file

# %%
# initialize a TruLens session and reset its database:
session = TruSession()
session.reset_database()
# Out:
# 🦑 Initialized with db url sqlite:///default.sqlite .
# 🛑 Secret keys may be written to the database. See the `database_redact_keys` option of `TruSession` to prevent this.
# Updating app_name and app_version in apps table: 0it [00:00, ?it/s]
# Updating app_id in records table: 0it [00:00, ?it/s]
# Updating app_json in apps table: 0it [00:00, ?it/s]

# %%
# simple document formatting function
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %% [markdown]
# ## 2. Set up the vector database (Qdrant)

# %%
# load a sentence embedding model for text representation
embedding = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L12-v2")

# %%
# Connect to Qdrant
qdrant_path = Path("/workspaces/Rubin-RAG/resources/rubin_qdrant")
qdrant_collection = "rubin_telescope"

# client.close()
client = QdrantClient(path=str(qdrant_path))

lcqdrant = Qdrant(client=client, 
                  collection_name=qdrant_collection, 
                  embeddings=embedding)
# lcqdrant = Qdrant.from_existing_collection(
#     collection_name=qdrant_collection, embedding=embedding, path=qdrant_path
# )

# %%
# set up a retriever for fetching relevant documents
retriever = lcqdrant.as_retriever(search_type="mmr", search_kwargs={"k": 2})

# %% [markdown]
# ## 3. Setup the LLM (OLMo-7B-Instruct) model

# %%
# download the OLMo model
model_path = download_olmo_model()
# Out:
# Model already exists at /home/mambauser/.cache/ssec_tutorials/OLMo-7B-Instruct-Q4_K_M.gguf

# %%
# setup the Langchain llama.cpp model object: we are using the `OLMo-7B-Instruct` model.
# llama-cpp-python is a Python binding for llama.cpp C++ library as mentioned in previous modules.
olmo = LlamaCpp(
    model_path=str(model_path),  # the path to the OLMo model in GGUF file format
    callbacks=[StreamingStdOutCallbackHandler()],
    temperature=0.8,  # set the randomness of the model's output
    n_ctx=4096,  # set limit for the length of the input context
    max_tokens=512,  # set limit for the length of the generated text
    verbose=False,  # determines whether the model should print out debug information
    echo=False,  # determines whether the input prompt should be included in the output
)

# %% [markdown]
# ## 4. RAG pipeline

# %%
# Define the RAG class
class RAG:
    @instrument
    # Retrieve relevant text from vector store
    def retrieve(self, query: str) -> list:
        results = vector_store.query(query_texts=query, n_results=4)
        return [doc for sublist in results["documents"] for doc in sublist] # return them as a list of text chunks

rag = RAG()

# %%
# Define a prompt template
custom_prompt = PromptTemplate(
    input_variables=["context", "question"],
    template="You are an astrophysics expert."
             "Please answer the question on astrophysics based on the following context:\n\n"
             "Context: {context}\n"
             "Question: {question}\n"
)

# %%
# RAG chain definition
rag_chain = (
    {
        "context": retriever | format_docs,  # retrieve and format the context
        "question": RunnablePassthrough() # Pass the user’s question directly
    }
    | custom_prompt
    | olmo 
    | StrOutputParser()  # Parse and extract only the final model output
)

# %% [markdown]
# ## 5. TruLens Feedback Evaluation pipeline
#
# I will be initializing a provider class using OpenAI. It uses OpenAI’s language model to evaluate responses (provide feedback scores based on OpenAI-generated judgments)

# %%
# initialize provider class
provider = OpenAI()

# %%
# select context to be used in feedback
context = TruChain.select_context(rag_chain)

# %% [markdown]
# ### 5.1 Feedback Functions

# %%
# define a groundedness feedback function
# that checks if the answer is factually supported by retrieved documents.
f_groundedness = (
    Feedback(
        provider.groundedness_measure_with_cot_reasons, name="Groundedness"
    )
    .on(context.collect())  # collect context chunks into a list
    .on_output()
)
# Out:
# ✅ In Groundedness, input source will be set to __record__.app.first.steps__.context.first.invoke.rets[:].page_content.collect() .
# ✅ In Groundedness, input statement will be set to __record__.main_output or `Select.RecordOutput` .

# %%
# define a question/answer relevance function
# that evaluates how relevant the RAG's answer is to the question
f_answer_relevance = Feedback(
    provider.relevance_with_cot_reasons, name="Answer Relevance"
).on_input_output()
# Out:
# ✅ In Answer Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Answer Relevance, input response will be set to __record__.main_output or `Select.RecordOutput` .

# %%
# define a context relevance feedback function 
# evaluates how relevant the context is to the question
f_context_relevance = (
    Feedback(
        provider.context_relevance_with_cot_reasons, name="Context Relevance"
    )
    .on_input()
    .on(context)
    .aggregate(np.mean)
)
# Out:
# ✅ In Context Relevance, input question will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Context Relevance, input context will be set to __record__.app.first.steps__.context.first.invoke.rets[:].page_content .

# %% [markdown]
# ### 5.2 Set up a TruLens evaluation recorder
# Next we will create a TruLens evaluation recorder that monitors and logs the performance of out RAG system.

# %%
tru_recorder = TruChain(
    rag_chain,
    app_name="RubinChat",
    app_version="v1",
    feedbacks=[f_answer_relevance, f_context_relevance, f_groundedness],
)
# Out:
# instrumenting <class 'langchain_core.runnables.base.RunnableParallel'> for base <class 'langchain_core.runnables.base.RunnableParallel'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_core.runnables.base.RunnableParallel'> for base <class 'langchain_core.runnables.base.RunnableSerializable'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_core.runnables.base.RunnableParallel'> for base <class 'langchain_core.load.serializable.Serializable'>
# instrumenting <class 'langchain_core.vectorstores.base.VectorStoreRetriever'> for base <class 'langchain_core.vectorstores.base.VectorStoreRetriever'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# 	instrumenting _get_relevant_documents
# 	instrumenting get_relevant_documents
# 	instrumenting aget_relevant_documents
# 	instrumenting _aget_relevant_documents
# instrumenting <class 'langchain_core.vectorstores.base.VectorStoreRetriever'> for base <class 'langchain_core.retrievers.BaseRetriever'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# 	instrumenting _get_relevant_documents
# 	instrumenting get_relevant_documents
# 	instrumenting aget_relevant_documents
# 	instrumenting _aget_relevant_documents
# instrumenting <class 'langchain_core.vectorstores.base.VectorStoreRetriever'> for base <class 'langchain_core.runnables.base.RunnableSerializable'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_core.vectorstores.base.VectorStoreRetriever'> for base <class 'langchain_core.load.serializable.Serializable'>
# instrumenting <class 'langchain_core.runnables.base.RunnableSequence'> for base <class 'langchain_core.runnables.base.RunnableSequence'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_core.runnables.base.RunnableSequence'> for base <class 'langchain_core.runnables.base.RunnableSerializable'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_core.runnables.base.RunnableSequence'> for base <class 'langchain_core.load.serializable.Serializable'>
# instrumenting <class 'langchain_core.runnables.passthrough.RunnablePassthrough'> for base <class 'langchain_core.runnables.passthrough.RunnablePassthrough'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_core.runnables.passthrough.RunnablePassthrough'> for base <class 'langchain_core.runnables.base.RunnableSerializable'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_core.runnables.passthrough.RunnablePassthrough'> for base <class 'langchain_core.load.serializable.Serializable'>
# instrumenting <class 'langchain_core.output_parsers.string.StrOutputParser'> for base <class 'langchain_core.output_parsers.string.StrOutputParser'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_core.output_parsers.string.StrOutputParser'> for base <class 'langchain_core.output_parsers.transform.BaseTransformOutputParser'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_core.output_parsers.string.StrOutputParser'> for base <class 'langchain_core.output_parsers.base.BaseOutputParser'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_core.output_parsers.string.StrOutputParser'> for base <class 'langchain_core.runnables.base.RunnableSerializable'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_core.output_parsers.string.StrOutputParser'> for base <class 'langchain_core.load.serializable.Serializable'>
# instrumenting <class 'langchain_core.runnables.base.RunnableSequence'> for base <class 'langchain_core.runnables.base.RunnableSequence'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_core.runnables.base.RunnableSequence'> for base <class 'langchain_core.runnables.base.RunnableSerializable'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_core.runnables.base.RunnableSequence'> for base <class 'langchain_core.load.serializable.Serializable'>
# instrumenting <class 'langchain_core.prompts.prompt.PromptTemplate'> for base <class 'langchain_core.prompts.prompt.PromptTemplate'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_core.prompts.prompt.PromptTemplate'> for base <class 'langchain_core.prompts.string.StringPromptTemplate'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_core.prompts.prompt.PromptTemplate'> for base <class 'langchain_core.prompts.base.BasePromptTemplate'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_core.prompts.prompt.PromptTemplate'> for base <class 'langchain_core.runnables.base.RunnableSerializable'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_core.prompts.prompt.PromptTemplate'> for base <class 'langchain_core.load.serializable.Serializable'>
# instrumenting <class 'langchain_community.llms.llamacpp.LlamaCpp'> for base <class 'langchain_community.llms.llamacpp.LlamaCpp'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_community.llms.llamacpp.LlamaCpp'> for base <class 'langchain_core.language_models.llms.LLM'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_community.llms.llamacpp.LlamaCpp'> for base <class 'langchain_core.language_models.llms.BaseLLM'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_community.llms.llamacpp.LlamaCpp'> for base <class 'langchain_core.language_models.base.BaseLanguageModel'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_community.llms.llamacpp.LlamaCpp'> for base <class 'langchain_core.runnables.base.RunnableSerializable'>
# 	instrumenting invoke
# 	instrumenting ainvoke
# 	instrumenting stream
# 	instrumenting astream
# instrumenting <class 'langchain_community.llms.llamacpp.LlamaCpp'> for base <class 'langchain_core.load.serializable.Serializable'>

# %% [markdown]
# ## 6. Test and Evaluate RAG Responses
# ### 6.1 Load questions from the LSST community forum dataset

# %%
# load the CSV file
lsst_forum_responses_path = "data/input/lsst_forum_responses.csv"
qa_df = pd.read_csv(lsst_forum_responses_path)
print(qa_df.shape)
# print(qa_df.columns)
qa_df.head()
# Out:
# (10612, 14)
#    category_id                                    question_header  \
# 0           55  Lasair watchlist with large search radius vers...
# 1           55  Lasair watchlist with large search radius vers...
# 2           55  Lasair watchlist with large search radius vers...
# 3           55  Lasair watchlist with large search radius vers...
# 4           10  Science Pipeline Release 29.0.0 Status and Dis...
#
#    question_author_id                                           question  \
# 0                2517  <p>Hi, I want to define Lasair filters for a g...
# 1                2517  <p>Hi, I want to define Lasair filters for a g...
# 2                2517  <p>Hi, I want to define Lasair filters for a g...
# 3                2517  <p>Hi, I want to define Lasair filters for a g...
# 4                1185  <p>We are starting the science pipelines relea...
#
#   question_date                                             answer  \
# 0    2025-03-07  <p>Thanks Roy.</p>\n<p>I’m experimenting with ...
# 1    2025-03-07  <p>I think the maximum radius is 1000 arc seco...
# 2    2025-03-07  <p>Thanks Roy,</p>\n<p>it looks like the maxim...
# 3    2025-03-07  <p>Hi Ismael<br>\nBoth watchlist and watchmap ...
# 4    2025-03-05  <p>Release candidate v29_0_0_rc1 is now availa...
#
#   answer_author_username answer_date community_role community_visual_badge  \
# 0          iperezfournon  2025-03-10            NaN                    NaN
# 1                    roy  2025-03-10            NaN                    NaN
# 2          iperezfournon  2025-03-10            NaN                    NaN
# 3                    roy  2025-03-08            NaN                    NaN
# 4               mwittgen  2025-03-05         LSSTDM                 LSSTDM
#
#    is_moderator  is_admin  is_staff  is_accepted_answer
# 0         False     False     False               False
# 1         False     False     False               False
# 2         False     False     False               False
# 3         False     False     False                True
# 4         False     False     False               False

# %%
# now I don't want all the rows, I just want rows with accepted answer
accepted_qa_df = qa_df[qa_df["is_accepted_answer"] == True]

# accepted_qa_df = accepted_qa_df[accepted_qa_df["category_id"] == 23]
accepted_qa_df.reset_index(drop=True, inplace=True)

print(accepted_qa_df.shape)
accepted_qa_df.head()
# Out:
# (513, 14)
#    category_id                                    question_header  \
# 0           55  Lasair watchlist with large search radius vers...
# 1            6  Where to find the Vera C. Rubin Observatory na...
# 2            6  Rubin Data Rights for Rubin source IDs and pla...
# 3            6  RubinObservatory.org site issue with Chrome on...
# 4           60  UK IDAC offline for maintenance during 4th--5t...
#
#    question_author_id                                           question  \
# 0                2517  <p>Hi, I want to define Lasair filters for a g...
# 1                 440  <p>There used to be a the <a href="https://pro...
# 2                2316  <p>I am currently writing a proposal for a NAS...
# 3                 229  <p>Hello, Rubin website team-</p>\n<p>This is ...
# 4                 245  <p>Apologies for short notice. Due to planned ...
#
#   question_date                                             answer  \
# 0    2025-03-07  <p>Hi Ismael<br>\nBoth watchlist and watchmap ...
# 1    2025-03-01  <p>Hi Meg, thanks for this.</p>\n<p>I can conf...
# 2    2025-02-25  <p>Hi <a class="mention" href="/u/kkruszynska"...
# 3    2025-02-06  <p>Hi <a class="mention" href="/u/tomloredo">@...
# 4    2025-02-04  <p>The UK IDAC is now back online. Apologies f...
#
#   answer_author_username answer_date community_role community_visual_badge  \
# 0                    roy  2025-03-08            NaN                    NaN
# 1          MelissaGraham  2025-03-01         LSSTDM                    CST
# 2             jeffcarlin  2025-02-25         LSSTDM                    CST
# 3          MelissaGraham  2025-02-06         LSSTDM                    CST
# 4         george_beckett  2025-02-06            NaN                    NaN
#
#    is_moderator  is_admin  is_staff  is_accepted_answer
# 0         False     False     False                True
# 1          True      True      True                True
# 2          True     False      True                True
# 3          True      True      True                True
# 4          True     False      True                True

# %%
# also seems like we have a lot of rows. For testing purposes, I will sample 5 rows.
random_seed = 42

sampled_accepted_qa_df = accepted_qa_df.sample(n=5, random_state=random_seed)
sampled_accepted_qa_df.reset_index(drop=True, inplace=True)

print(sampled_accepted_qa_df.shape)
sampled_accepted_qa_df.head()
# Out:
# (5, 14)
#    category_id                                    question_header  \
# 0            6  Single_frame task produces different results e...
# 1            6   Issue building 11_0 on Mac OS X Yosemite 10.10.5
# 2           34  Access to forced photometry and postage stamps...
# 3           49                            Listing available repos
# 4            6  Setup: Unable to take shared lock on $STACKDIR...
#
#    question_author_id                                           question  \
# 0                 443  <p>Hi,<br>\nI’m following this tutorial: <a hr...
# 1                   4  <p>I seem to have a linker error when I instal...
# 2                 381  <p>Final couple of questions for now, on broke...
# 3                 247  <p>Hi there,</p>\n<p>Is there some way I find ...
# 4                  80  <p>Has anyone seen the eups based error before...
#
#   question_date                                             answer  \
# 0    2022-08-11  <p>Quick comment on the code:</p>\n<aside clas...
# 1    2015-10-05  <p>It seemed to be solved by one or any of:</p...
# 2    2020-02-19  <p>Hi Stephen, I have some answers from the DM...
# 3    2024-01-24  <p>Hi James<br>\nmaybe<br>\n<code>dafButler.Bu...
# 4    2015-09-18  <p>Eups locking is known to be broken.  There ...
#
#   answer_author_username answer_date community_role community_visual_badge  \
# 0                   timj  2022-08-20         LSSTDM                 LSSTDM
# 1                  jsick  2015-10-06         LSSTDM                 LSSTDM
# 2          MelissaGraham  2020-02-19         LSSTDM                    CST
# 3                  MRead  2024-01-24            NaN                    NaN
# 4                 jbosch  2015-09-18         LSSTDM                 LSSTDM
#
#    is_moderator  is_admin  is_staff  is_accepted_answer
# 0         False     False     False                True
# 1          True      True      True                True
# 2          True      True      True                True
# 3         False     False     False                True
# 4         False     False     False                True

# %%
print(sampled_accepted_qa_df.shape)
sampled_accepted_qa_df.head()
# Out:
# (5, 14)
#    category_id                                    question_header  \
# 0            6  Single_frame task produces different results e...
# 1            6   Issue building 11_0 on Mac OS X Yosemite 10.10.5
# 2           34  Access to forced photometry and postage stamps...
# 3           49                            Listing available repos
# 4            6  Setup: Unable to take shared lock on $STACKDIR...
#
#    question_author_id                                           question  \
# 0                 443  Hi, \nI’m following this tutorial:  The LSST S...
# 1                   4  I seem to have a linker error when I install v...
# 2                 381  Final couple of questions for now, on broker r...
# 3                 247  Hi there, \n Is there some way I find out what...
# 4                  80  Has anyone seen the eups based error before: \...
#
#   question_date                                             answer  \
# 0    2022-08-11  Quick comment on the code: \n \n \n \n  petarz...
# 1    2015-10-05  It seemed to be solved by one or any of: \n \n...
# 2    2020-02-19  Hi Stephen, I have some answers from the DM te...
# 3    2024-01-24  Hi James \nmaybe \n dafButler.Butler.get_known...
# 4    2015-09-18  Eups locking is known to be broken.  There are...
#
#   answer_author_username answer_date community_role community_visual_badge  \
# 0                   timj  2022-08-20         LSSTDM                 LSSTDM
# 1                  jsick  2015-10-06         LSSTDM                 LSSTDM
# 2          MelissaGraham  2020-02-19         LSSTDM                    CST
# 3                  MRead  2024-01-24            NaN                    NaN
# 4                 jbosch  2015-09-18         LSSTDM                 LSSTDM
#
#    is_moderator  is_admin  is_staff  is_accepted_answer
# 0         False     False     False                True
# 1          True      True      True                True
# 2          True      True      True                True
# 3         False     False     False                True
# 4         False     False     False                True

# %% [markdown]
# ### 6.2 Test the RAG pipeline

# %%
# run RAG pipeline on all the sampled Q&A
responses = []

for _, row in sampled_accepted_qa_df.iterrows():
    question = row["question"]
    true_answer = row["answer"]

    # run the RAG pipeline with TruLens recording
    print("\n\nQuestion: ", question)
    context = retriever.invoke(question)
    with tru_recorder as recording:
        rag_response = rag_chain.invoke(question)

    # Store results ina  dict and append to a list
    responses.append({
        "question": question,
        "context":format_docs(context),
        "true_answer": true_answer,
        "RAG_generated_answer": rag_response
    })

# convert the responses into a DataFrame
responses_df = pd.DataFrame(responses)
# Out:
# Question:  Hi,
# I’m following this tutorial:  The LSST Science Pipelines — LSST Science Pipelines  and I’ve ran the first step “single_frame” task a few times. Each time it runs it produces different results: if I go through all calexps in the output collection ( butler.registry.queryDatasets("calexp", collections=collection) ), and look at their sky coverage (calexp width, height and WCS mapping), and then find the total coverage of the whole collection (max and min ra, dec coordinates), I get different results each time it runs. And I’m starting it like this (verbatim what’s in the tutorial):
#  pipetask run -b $RC2_SUBSET_DIR/SMALL_HSC/butler.yaml \
#              -p $RC2_SUBSET_DIR/pipelines/DRP.yaml#singleFrame \
#              -i HSC/RC2/defaults \
#              -o u/$USER/single_frame \
#              --register-dataset-types
#
#  What could be the explanation for this behavior?
#  Thanks,
# Petar
# Answer:
# Based on your description, it seems like you are observing a change in the sky coverage of the outputs from each execution of the single_frame task. The difference in the sky coverage might be attributed to the following reasons:
#
# 1. Random seed setting: By default, when running the pipeline, the LSST Science Pipelines use a fixed random seed for generating random numbers that influence the data generation and processing steps. When you run the same single_frame task multiple times, the random numbers generated from the same random seed might produce slightly different results each time because of this randomness.
# 2. Changes in pipeline configuration or dependencies: If you modified any parameters or added/removed dependencies between pipeline runs, these changes may affect the behavior and output of the pipeline. This could lead to varying sky coverage results for the same task run.
# 3. Updates to data products or processing steps: The LSST Science Pipelines are continuously being updated with new features or bug fixes. If you ran your first single_frame task before these updates, there may be differences in the generated output compared to more recent pipeline runs.
# 4. Time-based variation in input data: Since each single_frame task is executed independently of others, it is possible that the input data for some instances might have different characteristics than for other tasks. For example, if you are working with a large dataset or if there are inconsistencies between datasets within your project, these issues could lead to differences in the sky coverage for individual single_frame tasks.
# 5. Pipeline configuration error: If your pipeline configuration is not correct, it might cause unexpected behavior and results. In this case, you can try rerunning the entire pipeline with a new configuration file or consulting the documentation for any known issues that could affect the output of the task.
#
# In summary, there might be several contributing factors to the variation in sky coverage between different single_frame tasks you have executed. It would help if you first examined your pipeline configuration and input data to identify if these aspects contribute to the observed differences. If needed, you can try rerunning the entire pipeline with a new random seed or by modifying less critical parameters to isolate any potential changes that might be causing the issue.
#
# Question:  I seem to have a linker error when I install v11_0 of the stack from source on OS X Yosemite 10.10.5. My compiler is
#  » gcc --version                                                                                                                                                                                                                                                                                                     jsick@Helvetica ~EUPS_PATH 9 ↵
# Configured with: --prefix=/Applications/Xcode.app/Contents/Developer/usr --with-gxx-include-dir=/usr/include/c++/4.2.1
# Apple LLVM version 6.0 (clang-600.0.54) (based on LLVM 3.5svn)
# Target: x86_64-apple-darwin14.5.0
# Thread model: posix
#
#  Error message is:
#  » eups distrib install -t v11_0 lsst_apps                                                                                                                                                                                                                                                                              jsick@Helvetica ~EUPS_PATH
#   [  1/53 ]  cfitsio 3360.lsst3                                         done.
#   [  2/53 ]  doxygen 1.8.5 (already installed)                          done.
#   [  3/53 ]  eigen 3.2.0                                                done.
#   [  4/53 ]  fftw 3.3.4.lsst1                                           done.
#   [  5/53 ]  gsl 1.16.lsst2                                             done.
#   [  6/53 ]  minuit2 5.28.00.lsst1                                      done.
#   [  7/53 ]  mysqlclient 5.1.73.lsst2                                   done.
#   [  8/53 ]  python 0.0.3 (already installed)                           done.
#   [  9/53 ]  swig 3.0.2.lsst1                                           done.
#   [ 10/53 ]  xpa 2.1.15.lsst2                                           done.
#   [ 11/53 ]  boost 1.59.lsst1                                           done.
#   [ 12/53 ]  mysqlpython 1.2.3.lsst1 ...
#
# ***** error: from /Users/jsick/lsst/lsst_stack/EupsBuildDir/DarwinX86/mysqlpython-1.2.3.lsst1/build.log:
# running build_ext
# building '_mysql' extension
# creating build/temp.macosx-10.5-x86_64-2.7
# cc -fno-strict-aliasing -I/Users/jsick/lsst/lsst_stack/DarwinX86/anaconda/2.2.0/include -arch x86_64 -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -Dversion_info=(1,2,3,'final',0) -D__version__=1.2.3 -I/Users/jsick/lsst/lsst_stack/DarwinX86/mysqlclient/5.1.73.lsst2/include/mysql -I/Users/jsick/lsst/lsst_stack/DarwinX86/anaconda/2.2.0/include/python2.7 -c _mysql.c -o build/temp.macosx-10.5-x86_64-2.7/_mysql.o -g -D_P1003_1B_VISIBLE -DSIGNAL_WITH_VIO_CLOSE -DSIGNALS_DONT_BREAK_READ -DIGNORE_SIGHUP_SIGQUIT -DDONT_DECLARE_CXA_PURE_VIRTUAL
# In file included from _mysql.c:36:
# /Users/jsick/lsst/lsst_stack/DarwinX86/mysqlclient/5.1.73.lsst2/include/mysql/my_config.h:1088:9: warning: 'HAVE_WCSCOLL' macro redefined
# #define HAVE_WCSCOLL /**/
#         ^
# /Users/jsick/lsst/lsst_stack/DarwinX86/anaconda/2.2.0/include/python2.7/pyconfig.h:911:9: note: previous definition is here
# #define HAVE_WCSCOLL 1
#         ^
# _mysql.c:1421:10: warning: comparison of unsigned expression < 0 is always false [-Wtautological-compare]
#         if (how < 0 || how >= sizeof(row_converters)) {
#             ~~~ ^ ~
# 2 warnings generated.
# cc -bundle -undefined dynamic_lookup -L/Users/jsick/lsst/lsst_stack/DarwinX86/anaconda/2.2.0/lib -arch x86_64 -arch x86_64 build/temp.macosx-10.5-x86_64-2.7/_mysql.o -L/Users/jsick/lsst/lsst_stack/DarwinX86/mysqlclient/5.1.73.lsst2/lib/mysql -L/Users/jsick/lsst/lsst_stack/DarwinX86/anaconda/2.2.0/lib -lmysqlclient_r -lz -lm -o build/lib.macosx-10.5-x86_64-2.7/_mysql.so
# ld: library not found for -lgcc_s.10.5
# clang: error: linker command failed with exit code 1 (use -v to see invocation)
# error: command 'cc' failed with exit status 1
# + exit -4
# eups distrib: Failed to build mysqlpython-1.2.3.lsst1.eupspkg: Command:
#         source /Users/jsick/lsst/lsst_stack/eups/bin/setups.sh; export EUPS_PATH=/Users/jsick/lsst/lsst_stack; (/Users/jsick/lsst/lsst_stack/EupsBuildDir/DarwinX86/mysqlpython-1.2.3.lsst1/build.sh) >> /Users/jsick/lsst/lsst_stack/EupsBuildDir/DarwinX86/mysqlpython-1.2.3.lsst1/build.log 2>&1 4>/Users/jsick/lsst/lsst_stack/EupsBuildDir/DarwinX86/mysqlpython-1.2.3.lsst1/build.msg
# exited with code 252
#
#
#  Any thoughts?
#
# An implementation of the UNION CSC (C language construct) which follows the procedure defined in this document, it is being:
#
# A CSC for OS X Yoset (since history) that passes the test by following the procedure defined in the LSMT_LIBRARY_PATH=(LYNXCrossPool):
#
# 1. The developer has been developing their craft with data from: https://eastrojournal.org/LSMT-Tr-final-building-ext-sw-2014-lsm-35-build-for-eups-dist-builder-installed-x-an-l
#
# --- X ... final e-ls-library-use(6): A developer has never worked on it.
#
# The problem appears to be usable with the latest  for eups, a CSC that follows the appropriate language of:
#
# In this “hand” build described:
#
# 1. The CSC is for OS X Yoset version 1.14.eick’s-ELS-CUSTOM14_r18_r19_r20_r21_lsst...cc -build_fishes -build_version was 1.6(LYNXCrossPool(lynyxtw23):
# A CSC for OS X Yoset's experience: Welcome to eups, a CSC for OS X Yoset's experience because I've worked with the last version of eups:
# -eums:
#    The "handports" v11_0 is free and eups for the LSMS to build v11_0 was a hand-in-date-maintenance-on-access-kit-unality-build-vibious-to-memory-based on the OS X Yoset. A CSC, which is available with the system in eups. The stack is for the LSST_library_use(version 1 of the language you’re_nothing is included by context is the following a package is eopys:
#
# [CLLVM] (v1)
# [MathJick's eopsh...
#
# [Thementl as follows:
#
# Therelt85-shims. ALAappa\'tchicken\'s-package(1-20-lock here-->
# [Maths](mathjsiphON+build packages>  4-lck
# `````your-version and vwrap-version of
#
# Question:  Final couple of questions for now, on broker related data access :
#  Section 3.3.4 in LSE-163 : notes that a “precovery service” will be available for a limited number of DIAForcedSources across ALL previous visits, and returns results within 24hrs of request. But can this be for any arbitrary sky position ? Or must it be a the position of either an existing DIASource or DIAObject?
#  All image data (raw, processed, difference) are available to download no later than 24 hrs from end of visit acquisition. But will there be a “postage stamp” type service based on the “precovery service”. e.g. can a broker send a request for  n  forced photometry measurements, and also request the triplet of images (target, reference, difference) for stamps of arbitrary size (within reason !) ?
#
# Answer:
#  The precovery service will provide results for DIAForcedSources that are within the past 30 days and have a nominal 𝑡𝑟𝑎𝑛𝑠𝑆𝑁 threshold of 5. To determine if a position is within this time frame, Rubin Observatory will use data from visits that occurred no less than 14 days prior to the current date. So, the service can be used for any arbitrary sky position as long as it falls within the past 30-day window.
#
# Regarding image data and forced photometry: Yes, Rubin Observatory will provide access to raw, processed, and difference images through a broker. There will be no "postage stamp" service based on the precovery service, but brokers can request any number of forced photometric measurements by submitting separate requests for each measurement they desire. They will also have the ability to download any image triplet (target, reference, difference) within reason. The exact size and time frame constraints for downloading images will depend on various factors like storage capacity, network bandwidth, etc., which are outlined in Section 5 of LSE-163.
#
# Question:  Hi there,
#  Is there some way I find out what butler repos are available to me? Or, more specifically, how can I list all the values for X that I can put into  butler = dafButler.Butler(X, collections='2.2i/runs/DP0.2') . How can I find out, for example, that I  can  put  dp02  in there, but not, say,   dp85 ?
#  Thanks!
#  James
#
# Answer:
# To list the available values for `collections` when creating a `Butler` object, you can use the configuration file (if one is provided) or set up default values. Here's an example of how to list all the default collections for LATISS with their corresponding manager classes in a Python dictionary:
#
# ```python
# from daf.config import DAFConfig
# from daf.butler.registry import ManagerRegistry, Registry
#
# # Set up the registry configuration
# registry_config = {
#     "manager": {
#         "default": {
#             "class": "lsst.daf.butler.registry.SQLManager",
#             "url": "sqlite:///your_database_file.db",  # Your database file path,
#             "schemaName": "public",                   # The default schema name (public)
#         }
#     },
# }
#
# # Set up the registry with the given configuration
# butler = dafButler.Butler('/repo/main/', collections=['2.2i/runs/DP0.2'])
#
# # Get all manager classes and their respective collections from the default registry
# manager_classes, collections = {}, {}
# for manager_class in Registry.get_all_manager_classes():
#     collection_name = manager_class.__module__ + '.' + manager_class.__qualname__
#     collections[manager_class.__module__] = collection_name
#
# # Print the available collections and their respective manager classes
# for (manager_class, collection) in collections.items():
#     print(f"{collection}: {manager_class.__module__}")
# ```
#
# This will list all the default values for `collections` when creating a `Butler` object with no arguments provided. If you're using the configuration file to specify additional options, the available collections and their respective manager classes might differ based on your configurations.
#
# Question:  Has anyone seen the eups based error before:
#  setup: Unable to take shared lock on $STACKDIR: an exclusive lock is held by [user=$USER, pid=26430]
#
#  Google allowed me to trace it to this file:
#
#
#  github.com
#
#
#  RobertLuptonTheGood/eups/blob/master/python/eups/lock.py
#  from __future__ import absolute_import, print_function
# import errno
# import glob
# import os
# import shutil
# import sys
# import time
# import re
# from . import hooks
# from . import utils
#
# #
# # Types of locks
# #
# LOCK_SH = 1                             # acquire a shared lock
# LOCK_EX = 2                             # acquire an exclusive lock
#
# _lockDir = ".lockDir"                   # name of lock directory
#
# def getLockPath(dirName, create=False):
#
#
#   This file has been truncated.  show original
#
#
#
#
#
#  I have had issues installing the stack and getting it to work (Ubuntu 12.04) and so have created a dedicated user account on my machine, and managed to install the stack successfully to this fresh user account.
#  The error shows up when typing any of the following things:
#  setup pipe_tasks
# source ..../loadLSST.bash
#
#  I have tried to kill the process id (always 26430) but it doesn’t exist.
#  I can’t say what happened before this error showed up as we have an undergrad working with the stack right now.
#  I also noticed a  .eups  directory in the home directory: perhaps something needs to be cleared from a cache in here?
#  Apologies if this issue is light on information, but this error seemed to come out of nowhere.
#
# Answer: Yes, I have seen the eups based error before. This error is due to an exclusive lock being held by another process. It may occur when trying to acquire a shared lock on the specified directory. To resolve this error, make sure that no other processes are running with the same lock file and try acquiring the lock again. Additionally, you can try deleting the ".eups" directory in your home folder to clear any cached data. If the issue persists, try deleting the lock files present under the lock directory, which could be causing the conflict.

# %%
# get records and feedback from TruLens
records, feedback = session.get_records_and_feedback()

# select required columns from the records df and merge with the ground truth df
records_selected = records[["app_id", "input"] + feedback]
full_trulens_results_df = responses_df.merge(records_selected, 
                                             left_on="question", 
                                             right_on="input", 
                                             how="left")

full_trulens_results_df.drop(columns=["input"], inplace=True)
full_trulens_results_df = full_trulens_results_df[["app_id", "question", "true_answer", "context", "RAG_generated_answer", "Answer Relevance", "Groundedness", "Context Relevance"]]
# full_trulens_results_df = full_trulens_results_df[full_trulens_results_df["app_id"] == ""]
full_trulens_results_df.rename(columns={"Answer Relevance": "trulens_Answer_Relevance", "Groundedness":"trulens_Groundedness", "Context Relevance":"trulens_Context_Relevance"}, inplace=True)
full_trulens_results_df.head()
# Out:
#                                       app_id  \
# 0  app_hash_249cdbf218ae5cad989db0fbaf09493b
# 1  app_hash_249cdbf218ae5cad989db0fbaf09493b
# 2  app_hash_249cdbf218ae5cad989db0fbaf09493b
# 3  app_hash_249cdbf218ae5cad989db0fbaf09493b
# 4  app_hash_249cdbf218ae5cad989db0fbaf09493b
#
#                                             question  \
# 0  Hi, \nI’m following this tutorial:  The LSST S...
# 1  I seem to have a linker error when I install v...
# 2  Final couple of questions for now, on broker r...
# 3  Hi there, \n Is there some way I find out what...
# 4  Has anyone seen the eups based error before: \...
#
#                                          true_answer  \
# 0  Quick comment on the code: \n \n \n \n  petarz...
# 1  It seemed to be solved by one or any of: \n \n...
# 2  Hi Stephen, I have some answers from the DM te...
# 3  Hi James \nmaybe \n dafButler.Butler.get_known...
# 4  Eups locking is known to be broken.  There are...
#
#                                              context  \
# 0  Draft\nLVV-P106: Data Management Acceptance Te...
# 1  DMTN-001: Porting the stack to OS X El Capitan...
# 2  Data Policy | RDO-13 (rel 1.2.2) | Latest Revi...
# 3  3   Overview\nThe Butler is implemented as thr...
# 4  4/11/24, 2:31 PM\nRSP identity management impl...
#
#                                 RAG_generated_answer  \
# 0  \nAnswer:\nBased on your description, it seems...
# 1  \nAn implementation of the UNION CSC (C langua...
# 2  \nAnswer: \n The precovery service will provid...
# 3  \nAnswer:\nTo list the available values for `c...
# 4  \nAnswer: Yes, I have seen the eups based erro...
#
#    trulens_Answer_Relevance  trulens_Groundedness  trulens_Context_Relevance
# 0                       1.0              0.052632                   0.333333
# 1                       0.0              0.000000                   0.166667
# 2                       1.0              0.285714                   0.333333
# 3                       1.0              0.166667                   0.500000
# 4                       NaN                   NaN                        NaN

# %% [markdown]
# ### 6.3 TruLens Evaluation

# %%
session.get_leaderboard()
# Out:
#                        Answer Relevance  Context Relevance  Groundedness  \
# app_name  app_version
# RubinChat v1                       0.75           0.333333      0.126253
#
#                           latency  total_cost
# app_name  app_version
# RubinChat v1           262.378483         0.0

# %%
# more inteactive UI
session.run_dashboard()
# Out:
# Starting dashboard ...
# Accordion(children=(VBox(children=(VBox(children=(Label(value='STDOUT'), Output())), VBox(children=(Label(valu…
# Dashboard started at http://localhost:46121 .
# <Popen: returncode: None args: ['streamlit', 'run', '--server.headless=True'...>

# %% [markdown]
# ## 7. Save the results

# %%
timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
file_name = f"data/results/trulens_results_{timestamp}.csv"
full_trulens_results_df.to_csv(file_name, index=False)
